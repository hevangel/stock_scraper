# %%
import pandas as pd
df = pd.read_csv('data_finviz/finviz_2020-04-27.csv')

# %%
sector_list = df.Sector.unique()

# %%
industry_list = df[df['Sector'] == sector_list[0]].Industry.unique()

# %%
for index, row in df[(df['Sector'] == sector_list[0]) & (df['Industry'] == industry_list[0])].iterrows():
    print(row)
# Out:
# Ticker                                      A
# Date                               2020-04-27
# Company            Agilent Technologies, Inc.
# Sector                             Healthcare
# Industry      Medical Laboratories & Research
# Country                                   USA
# Market Cap                             23.64B
# P/E                                     31.47
# Price                                   76.25
# Change                                  0.66%
# Volume                                1289065
# Name: 0, dtype: object
# Ticker                                   ANIX
# Date                               2020-04-27
# Company               Anixa Biosciences, Inc.
# Sector                             Healthcare
# Industry      Medical Laboratories & Research
# Country                                   USA
# Market Cap                             40.60M
# P/E                                         -
# Price                                    2.01
# ...

# %%
print(rows)
# Out:
#      Ticker        Date                                         Company  \
# 0         A  2020-04-27                      Agilent Technologies, Inc.
# 326    ANIX  2020-04-27                         Anixa Biosciences, Inc.
# 380     ARA  2020-04-27        American Renal Associates Holdings, Inc.
# 544    AXDX  2020-04-27                    Accelerate Diagnostics, Inc.
# 668    BEAT  2020-04-27                              BioTelemetry, Inc.
# 734     BIO  2020-04-27                      Bio-Rad Laboratories, Inc.
# 735   BIO-B  2020-04-27                      Bio-Rad Laboratories, Inc.
# 736    BIOC  2020-04-27                                   Biocept, Inc.
# 817    BNGO  2020-04-27                          Bionano Genomics, Inc.
# 870    BRKR  2020-04-27                              Bruker Corporation
# 961    BWAY  2020-04-27                                  Brainsway Ltd.
# 1042   CBAT  2020-04-27                    CBAK Energy Technology, Inc.
# ...
