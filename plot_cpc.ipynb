# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
cpc_list = ['total','index','equity','etp','spx','vix']
df_cpc_list = {}
df = pd.DataFrame()
for cpc in cpc_list:
    df_cpc_list[cpc] = pd.read_csv('../stock_data/data_cpc/'+cpc+'.csv', index_col=0, parse_dates=True)
    df[cpc] = df_cpc_list[cpc]['PCRatio']

# %%
plt.rcParams["figure.figsize"] = (20,150)
df['2020'].plot()
